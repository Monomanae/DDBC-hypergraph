# %%
import numpy as np
import networkx as nx
import pickle
from matplotlib import pyplot as plt
from matplotlib.patches import Wedge, Patch
import json
import os
from collections import defaultdict

# %% [markdown]
# # Loading

# %%
graph_dir = "../../Graphs"

# %%
with open("../../Data/disease_to_snomed_id.json", "r") as f:
    d = json.load(f)

DISEASE_list = list(d.keys())
print(DISEASE_list)
# Out:
# ['BIPOLAR', 'SCHIZOPHRENIA', 'LEUKEMIA', 'PARKINSON', 'DIABETES', 'BREASTCANCER']

# %%
with open("../output/disease_to_comm_dgidb_gene_count.json", "r") as f:
    disease_to_comm_dgidb_gene_count = json.load(f)

# %%
sims = []
cat_dicts = []
sizes_list = []  # or None per plot
num_dgidb_genes_dict= []

# %%
def community_similarity_matrix(G, communities, normalize=True):
    """
    Compute community–community similarity as specified by PI:
        sim[i, j] = (sum of edge weights between members of communities i and j)
                    / (|Ci| * |Cj|)

    Then:
      - diagonal is forced to 0
      - matrix is normalized so that max(sim) = 1 (if normalize=True)
    """
    n = len(communities)
    sim = np.zeros((n, n), dtype=float)

    # ----- compute similarities -----
    for i in range(n):
        A = communities[i]
        sizeA = len(A)
        for j in range(i + 1, n):
            B = communities[j]
            sizeB = len(B)

            total_weight = 0.0
            for u in A:
                for v in B:
                    if G.has_edge(u, v):
                        total_weight += G[u][v].get("weight")

            value = total_weight / (sizeA * sizeB)
            sim[i, j] = value
            sim[j, i] = value

    # ----- set diagonal to zero -----
    np.fill_diagonal(sim, 0.0)

    # ----- normalization -----
    if normalize:
        max_val = sim.max()
        if max_val > 0:
            sim = sim / max_val
        # if max_val == 0 → leave as all zeros

    return sim

# %%
for DISEASE in DISEASE_list:
    DISEASE_FOLDER = f"../output/{DISEASE}/"
    RESULT_FOLDER = DISEASE_FOLDER + "leiden_results"
    with open(f"{RESULT_FOLDER}/result_communities_selected.pkl", "rb") as f:
        communities_selected = pickle.load(f)
    with open(f"{RESULT_FOLDER}/result_graph.pkl", "rb") as f:
        graph = pickle.load(f)
    with open(f"{DISEASE_FOLDER}/category_count_by_comm.pkl", "rb") as f:
        category_count_by_comm = pickle.load(f)
    comm_sim_mat = community_similarity_matrix(graph, communities_selected, normalize = True)
    sizes = [len(c) for c in communities_selected]
    
    sims.append(comm_sim_mat)  
    cat_dicts.append(category_count_by_comm)  
    sizes_list.append(sizes)   
    num_dgidb_genes = {int(k): v for k, v in disease_to_comm_dgidb_gene_count[DISEASE].items()}
    num_dgidb_genes_dict.append(num_dgidb_genes)

# %% [markdown]
# # Graphing

# %%
def plot_community_graph_circular(
    sim_matrix,
    category_count_by_comm,
    major,                 # NEW: global major categories list (sorted)
    color_map,             # NEW: global color map dict: cat -> color
    threshold=0.0,
    community_sizes=None,
    figsize=(7, 7),
    edge_label_digits=2,
    pct_threshold=0.15,
    show_legend=False,     # NEW: default off (so you can have one global legend elsewhere)
    ax=None,               # NEW: allow drawing on a provided axis
    save_path=None,        # NEW: optional save path
):
    sim = np.asarray(sim_matrix)
    n = sim.shape[0]

    # ---- Graph ----
    G = nx.Graph()
    G.add_nodes_from(range(n))
    for i in range(n):
        for j in range(i + 1, n):
            w = float(sim[i, j])
            if w > threshold:
                G.add_edge(i, j, weight=w)

    pos = nx.circular_layout(G)

    # ---- Radii ----
    if community_sizes is None:
        radii = np.full(n, 0.08)
    else:
        cs = np.maximum(np.asarray(community_sizes, float), 0)
        radii = (0.06 + 0.10 * (cs / cs.max())) if cs.max() > 0 else np.full(n, 0.08)

    other_color = "lightgray"

    # ---- Plot ----
    created_fig = False
    if ax is None:
        fig, ax = plt.subplots(figsize=figsize)
        created_fig = True
    else:
        fig = ax.figure

    edge_w = nx.get_edge_attributes(G, "weight")
    if edge_w:
        nx.draw_networkx_edges(G, pos, width=[4 * w for w in edge_w.values()], alpha=0.8, ax=ax)
        nx.draw_networkx_edge_labels(
            G,
            pos,
            edge_labels={e: f"{w:.{edge_label_digits}f}" for e, w in edge_w.items()},
            font_size=8,
            label_pos=0.5,
            ax=ax,
        )

    used_other = False

    def top_labels(x, y, r, num_terms, comm_size, num_dgidb_genes):
        y_top = y + 1.1 * r
        ax.text(x, y_top, f"terms={num_terms}", ha="center", va="bottom", fontsize=9)
        ax.text(x, y_top + 0.05, f"size={comm_size}", ha="center", va="bottom", fontsize=9)
        ax.text(x, y_top + 0.10, f"# DGIDB genes={num_dgidb_genes}", ha="center", va="bottom", fontsize=9)

    def fallback_node(x, y, r, node, num_terms, comm_size, num_dgidb_genes, face, hatch=None):
        ax.add_patch(plt.Circle((x, y), r, facecolor=face, edgecolor="black", hatch=hatch, linewidth=1.0))
        ax.text(x, y, str(node), ha="center", va="center", fontsize=8, weight="bold")
        top_labels(x, y, r, num_terms, comm_size, num_dgidb_genes)

    for node in G.nodes():
        x, y = pos[node]
        r = radii[node]
        d = category_count_by_comm.get(node, {})

        num_terms = sum(c for c, _ in d.values() if c > 0)
        comm_size = community_sizes[node] if (community_sizes is not None and node < len(community_sizes)) else None
        ndg = num_dgidb_genes[node]

        total_here = sum(c for c, _ in d.values() if c > 0) if d else 0
        if not d:
            fallback_node(x, y, r, node, num_terms, comm_size, ndg, face="white", hatch="///")
            continue
        if total_here <= 0:
            fallback_node(x, y, r, node, num_terms, comm_size, ndg, face="lightgray")
            continue

        cats, counts = [], []
        other_count = 0
        for cat, (c, _) in d.items():
            if c <= 0:
                continue
            # SAME rule as before, but using provided global `major`
            if (c / total_here) >= pct_threshold and cat in major:
                cats.append(cat)
                counts.append(c)
            else:
                other_count += c

        if not cats and other_count == 0:
            fallback_node(x, y, r, node, num_terms, comm_size, ndg, face="lightgray")
            continue

        if other_count > 0:
            cats.append("Other")
            counts.append(other_count)
            used_other = True

        total = float(sum(counts))
        if total <= 0:
            fallback_node(x, y, r, node, num_terms, comm_size, ndg, face="lightgray")
            continue

        start = 90.0
        for cat, c in zip(cats, counts):
            ang = 360.0 * (c / total)
            fc = other_color if cat == "Other" else color_map.get(cat, other_color)
            ax.add_patch(Wedge((x, y), r, start, start + ang, facecolor=fc, edgecolor="black", linewidth=0.5))
            start += ang

        ax.text(x, y, str(node), ha="center", va="center", fontsize=8, weight="bold")
        top_labels(x, y, r, num_terms, comm_size, ndg)

    # ---- Legend (optional) ----
    if show_legend:
        patches = [Patch(facecolor=color_map[c], edgecolor="black", label=c) for c in major]
        if used_other:
            patches.append(Patch(facecolor=other_color, edgecolor="black", label="Other"))
        if patches:
            ax.legend(
                handles=patches,
                bbox_to_anchor=(1.2, 1),
                loc="upper left",
                borderaxespad=0.0,
                fontsize=8,
                title="Categories",
            )

    ax.set_axis_off()

    if save_path is not None:
        fig.savefig(save_path, bbox_inches="tight")

    if created_fig:
        plt.show()

    # Return whether "Other" appeared, so caller can decide if legend should include it
    return used_other

# %%
pct_threshold = 0.03

# %%
def compute_global_major(cat_dicts, pct_threshold=0.15):
    major = set()
    for category_count_by_comm in cat_dicts:
        for d in category_count_by_comm.values():
            total = sum(c for c, _ in d.values() if c > 0)
            if total <= 0:
                continue
            for cat, (c, _) in d.items():
                if c > 0 and (c / total) >= pct_threshold:
                    major.add(cat)
    return sorted(major)

major = compute_global_major(cat_dicts, pct_threshold=pct_threshold)
print("Global major categories:", len(major))
# Out:
# Global major categories: 34

# %%
combined = list(plt.get_cmap("tab20b").colors) + list(plt.get_cmap("tab20c").colors)
color_map = {cat: combined[i % len(combined)] for i, cat in enumerate(major)}

# %%
used_other_any = False

for (DISEASE, sim, cat_by_comm, sizes, num_dgidb_genes) in zip(DISEASE_list, sims, cat_dicts, sizes_list, num_dgidb_genes_dict):
    used_other = plot_community_graph_circular(
        sim_matrix=sim,
        category_count_by_comm=cat_by_comm,
        major=major,
        color_map=color_map,
        threshold=0.01,
        community_sizes=sizes,
        pct_threshold=pct_threshold,
        show_legend=False,
        save_path= f"{graph_dir}/{DISEASE}/community_detection_result_new.png",
    )
    used_other_any = used_other_any or used_other

print("Saved plots to:", graph_dir)
# Out:
# Saved plots to: ../../Graphs

# %% [markdown]
# # Create legend

# %%
other_color = "lightgray"

patches = [Patch(facecolor=color_map[c], edgecolor="black", label=c) for c in major]
if used_other_any:
    patches.append(Patch(facecolor=other_color, edgecolor="black", label="Other"))

legend_fig = plt.figure(figsize=(4, 0.25 * len(patches)))
legend_fig.legend(
    handles=patches,
    loc="upper left",
    fontsize=8,
    title="Categories",
    frameon=False,
)
plt.axis("off")
legend_fig.savefig(f"{graph_dir}/legend.png", bbox_inches="tight", pad_inches=0.02)

# %%
graph_dir
# Out:
# '../../Graphs'

# %% [markdown]
# # Top categories

# %%
def compute_global_category_counts(cat_dicts):
    """
    Additional feature: return global total count per category across ALL inputs.
    Sums positive counts c over all communities in all dicts.
    """
    global_counts = defaultdict(int)
    for category_count_by_comm in cat_dicts:
        for d in category_count_by_comm.values():
            for cat, (c, _) in d.items():
                if c > 0:
                    global_counts[cat] += c
    return dict(global_counts)

# %%
DISEASE_list
# Out:
# ['BIPOLAR',
#  'SCHIZOPHRENIA',
#  'LEUKEMIA',
#  'PARKINSON',
#  'DIABETES',
#  'BREASTCANCER']

# %%
cat_dicts_neuro = [cat_dicts[i] for i in [0,2,3]]

# %%
global_counts_neuro = compute_global_category_counts(cat_dicts_neuro)

# %%
global_counts_neuro = dict(sorted(global_counts_neuro.items(), key = lambda x: x[1], reverse = True))

# %%
global_counts_neuro
# Out:
# {'biological regulation': 1256,
#  'cellular process': 711,
#  'cellular anatomical structure': 243,
#  'binding': 176,
#  'localization': 175,
#  'Signal Transduction': 168,
#  'response to stimulus': 151,
#  'Metabolism of proteins': 103,
#  'developmental process': 90,
#  'Immune System': 89,
#  'Metabolism of RNA': 79,
#  'catalytic activity': 72,
#  'Disease': 71,
#  'protein-containing complex': 69,
#  'Cell Cycle': 51,
#  'Vesicle-mediated transport': 46,
#  'Gene expression (Transcription)': 23,
#  'molecular function regulator activity': 22,
#  'Cellular responses to stimuli': 22,
#  'Developmental Biology': 20,
#  'Extracellular matrix organization': 20,
#  'molecular transducer activity': 19,
#  'multicellular organismal process': 16,
#  'Signal transduction': 15,
#  'Organelle biogenesis and maintenance': 15,
#  'biological process involved in interspecies interaction between organisms': 13,
#  'Folding, sorting and degradation': 12,
#  'Metabolism': 11,
#  'immune system process': 11,
#  'Programmed Cell Death': 11,
#  'Glycan biosynthesis and metabolism': 9,
#  'Cellular community - eukaryotes': 9,
#  'Sensory Perception': 9,
#  'Cardiovascular disease': 8,
#  'Autophagy': 8,
#  'DNA Repair': 7,
#  'Cancer: specific types': 7,
#  'Infectious disease: viral': 6,
#  'Cancer: overview': 6,
#  'Hemostasis': 6,
#  'transporter activity': 6,
#  'Signaling molecules and interaction': 5,
#  'Transcription': 4,
#  'homeostatic process': 4,
#  'Lipid metabolism': 3,
#  'Cell motility': 3,
#  'Translation': 3,
#  'Transport and catabolism': 3,
#  'Sensory system': 3,
#  'Infectious disease: bacterial': 3,
#  'Chromatin organization': 2,
#  'translation factor activity': 2,
#  'Environmental adaptation': 2,
#  'Neurodegenerative disease': 2,
#  'locomotion': 2,
#  'Immune system': 2,
#  'Substance dependence': 2,
#  'Development and regeneration': 1,
#  'Cell growth and death': 1,
#  'Infectious disease: parasitic': 1,
#  'molecular adaptor activity': 1,
#  'Neuronal System': 1}
